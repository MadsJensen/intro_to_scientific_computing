# %% [markdown]
# # Get the course materials
#
# Make sure you have >15GB space on your hard drive and copy the file `linuxmint.vdi` to a _suitable location_. __NB:__ To spare your backup, you may want to exclude this file from Time Machine (or equivalent in Windows).
#
# Copy the `notebooks`-folder from the USB drive or the link provided, and place it into the working folder you created for the course.

# %% [markdown]
# # The Linux Mint Virtual Machine (VM) (via VirtualBox)
#
# __This is strictly speaking only required for Windows-users, but will work on a Mac too.__
#
# A _virtual machine (VM)_ is a common way for academic software developers to distribute their work for, _e.g._, training purposes: they are certain that no time needs to be spent on installation problems. That is precisely our motivation too, in addition to the fact that data science is, and will continue to be, performed on Unix-based platforms (notably Linux & Max OS)...
#
# ## Installation of the C268/10 disk image
#
# Open the VirtualBox application, then
#
# * select "New", name the virtual OS as you please, make it of "Type: Linux" and "Version: Other Linux (64-bit)".
# * choose an amount of RAM to allocate (no more than half of the total on your machine, around 2048 MB should be OK)
# * under Hard disk, select "Use and existing virtual hard disk file" and browse to the file `linuxmint.vdi`
# * select the newly-created virtual machine, select "Settings" and "Shared folders"
#     * click on the plus-folder-sign
#     * set folder path to Other...
#     * __select the folder you previous created for this course__ and hit "Select Folder"
#     * set the "Folder Name" to `shared`, and tick the box "Auto-mount"
# * start the VM
#     * the `sh_shared`-folder on the desktop gives access to the host PC file system
#
# ## Logging in
#
#     Username: user
#     Password: user
#
# ## For future reference / FAQ
#
# You now have access to a fully functional Linux client. After the course, you may use it to get to know Linux better, if that's the sort of thing that tickles your fancy.
#
# ### No, you _cannot_ mess up your host OS
#
# You may very well (see below) botch up the guest, but the VM will never be able to harm your host. So hack away.
#
# ### Super User / root priviledge
#
# To make changes to the VM, such as installing software packages, you will need to have _administrative priviledges_. In Linux-speak, the 'Administrator' is known as `root` (not to be confused with the root of the file system, `/`). In many ([Ubuntu](https://www.ubuntu.com/)-based) distributions like [Mint](https://www.linuxmint.com/), the normal user account created during setup (in our VM, simply: `user`) gets so-called ___super user priviledge___. This simply means that by prepending the word `sudo` to any command will _temporarily elevate_ `user`s priviledge to that or `root`, _e.g._
#
# ```sudo apt-get install cowsay```
#
# ### Performance considerations
#
# Think about the consequences on available computing resources of running an OS within an OS.

# %% [markdown]
# # Conda and Anaconda
#
# ## What is `conda`?
#
# From the [project webpage](https://conda.io/docs/):
#
# >Conda is an open source ___package___ management system ___and environment management___ system that runs on Windows, macOS and Linux. Conda quickly installs, runs and updates packages and their ___dependencies___. Conda easily creates, saves, loads and switches between environments on your local computer. It was created for Python programs, but it can package and distribute software for any language.
#
# _Keywords: package; environment; management system; dependencies_
#
# ## Why do we want it?
#
# We are learning about computing, for which we will need to write [programs](computer-programs-and-data-types.ipynb). The specific language we will use for demonstrations and exercises is called [Python](https://en.wikipedia.org/wiki/Python_(programming_language). We use `conda` to ease the pain of installing and operating a Python-based programming environment on all 3 OS's. Much of the said 'pain' arises due to _interdependencies_: some software modules/packages _depend_ on others being present. This can quickly become very complicated without a tool like `conda`...
#
# ## Installation the user-friendly way: Anaconda
#
# We recommend installing the "full" [Anaconda framework](https://www.anaconda.com/download/), which, in addition to the `conda` package manager, includes `Anaconda Navigator`: a graphical front-end application for maintaining _environments_ (we'll get back what those are). It's a hefty >400 MB download.
#
# __Choose the 64-bit version of the Python 3.6 installer.__
#
# _Tested on Win 10, 5 Sep; v. 4.3.21_
#
#
# ## (Optional) Advanced Installation on macOS / OS X / Linux
#
# Follow instructions on the ["miniconda" downloads page](https://conda.io/miniconda.html). __Choose the 64-bit (bash) version of the Python 3.6 installer.__ You can always later install the GUI in the 'full' framework by issuing the following command in a terminal:
#
# ```bash
# conda install anaconda-navigator
# ```

# %% [markdown]
# ## Set up the `fddhs`-environment on Windows and Mac
#
# We've created an _environment_-definition, containing all the tools we'll need during this course (we'll discuss what this entails later). The Linux VM already has the environment installed and _activated_ by default.
#
# With `conda`/Anaconda, setting up the same environment on a Windows or Mac is as simple as using an _environment definition file_ as a template:
#
# * `environment-win.yaml` (Windows)
# * `environment.yaml` (macOS/Linux)
#
# With Anaconda Navigator, select `Environments`, then `Import` and enter the appropriate `yaml`-file. On the [command line](05-Command-line-interface-A.ipynb), the equivalent is:
#
# ```bash
# conda create -n fddhs -f environment.yaml
# ```

# %% [markdown]
# # Jupyter
#
# From the [Project Jupyter website](jupyter.org):
#
# >The Jupyter Notebook is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and explanatory text. Uses include: data cleaning and transformation, numerical simulation, statistical modeling, machine learning and much more.
#
# >The Notebook has support for over 40 programming languages, including those popular in Data Science such as Python, R, Julia and Scala.
#
# ## Course materials are _Jupyter notebooks_
#
# The [Jupyter Notebook](http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/What%20is%20the%20Jupyter%20Notebook.html) combines three components:
#
# * The notebook web application: An interactive web application for writing and running code interactively and authoring notebook documents.
# * Kernels: Separate processes started by the notebook web application that __runs users’ code__ in a given __language__ and returns output back to the notebook web application. The kernel also handles things like computations for interactive widgets, tab completion and introspection.
# * Notebook documents: Self-contained documents that contain a representation of all content visible in the notebook web application, including inputs and outputs of the computations, narrative text, equations, images, and rich media representations of objects. __Each notebook document has its own kernel__.
# * The Notebook has support for over 40 programming languages, including those popular in Data Science such as Python, R, Julia and Scala.
#
# ## [JupyterLab](https://github.com/jupyterlab/jupyterlab)
#
# JupyterLab can be considered the 'next generation' of the `notebook`-project. It is also a web application, _i.e._, it runs in your web browser (not 'on the web', though). We will use JupyterLab merely as a convenient way of running Jupyter notebooks in an integrated environment, but it can do much more...
#
# ## Let's get going, start JupyterLab!
#
# The steps to perform are
#
# 1. Activate the `fddhs` computational environment we created above
# 2. Start a '_server_' for the `JupyterLab` web app
#
# ### Windows
#
# * Start the `Anaconda Prompt`
# * Execute: `activate fddsh`
# * Execute: `jupyter lab`
#
# ### Mac and Linux (virtual machine)
#
# * Start the `Terminal`-application
# * Execute: `source activate fddsh`
# * Execute: `jupyter lab`
#
# ## Quitting JupyterLab
#
# Closing the browser window will not close the _notebook server_. Correspondingly, if you accidentally close the browser window/tab `JupyterLab` is in, you can return to it by going to the appropriate URL. The notebook server prints out the URL on startup (see the Prompt/Terminal output right after starting). By default, the first server you start will be found at
#
# ```
# http://localhost:8888
# ```
#
# To _really_ quit the server, either close the Prompt/Terminal window, or hit Ctrl-C _twice_ in the terminal.

# %% [markdown]
# # Exercise: Is this data-driven health science?
#
# Start JupyterLab, navigate to the `notebooks`-folder, and open the file
#
# ```04-Software-installations.ipynb```
#
# Scroll to the bottom of the page, and you will find yourself ... here! _...inception..._
#
# Try changing the input parameters to the following 'machine' (execute the machine by selecting hitting Shift-Enter anywhere inside the cell).
#
# #### Assume the 'machine' is based on data; would you use it to determine which _actions_ to take? Can you determine any rules it's operating under?

# %%
from fddhs import decision_machine

# %%
decision_machine(systolic_blood_pressure=130,
                 bmi=23, hearing_threshold=30)
